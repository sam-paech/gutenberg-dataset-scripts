# %%
import json
from datasets import Dataset, DatasetDict
from huggingface_hub import login

# Load the data
with open('scenes_with_rewrites.json', 'r') as f:
    results = json.load(f)

# Prepare the data in the new format
formatted_data = []

MIN_CHOSEN_LENGTH = 3000

lengths = []
for row_id, rows in results.items():
    for data in rows:
        if 'rejected' not in data:
            print(data)
            continue

        if len(data['chosen']) < MIN_CHOSEN_LENGTH:
            continue
        
        #if len(data['chosen']) > 17000:
        #    continue

        lengths.append(len(data['chosen']))

        formatted_row = {
            "source": "[GENERAL FICTION] " + row_id.strip('.zip'),
            "chosen": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['chosen']}],
            "rejected": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['rejected']}],
            "prompt": data['prompt']
        }

        formatted_data.append(formatted_row)


with open('scenes_with_rewrites_scifi.json', 'r') as f:
    results = json.load(f)


lengths = []
for row_id, rows in results.items():
    for data in rows:
        if 'rejected' not in data:
            print(data)
            continue
        
        if len(data['chosen']) < MIN_CHOSEN_LENGTH:
            continue

        #if len(data['chosen']) > 17000:
        #    continue

        lengths.append(len(data['chosen']))

        formatted_row = {
            "source": "[SCIFI] " + row_id.strip('.zip'),
            "chosen": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['chosen']}],
            "rejected": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['rejected']}],
            "prompt": data['prompt']
        }

        formatted_data.append(formatted_row)


with open('scenes_with_rewrites_fantasy.json', 'r') as f:
    results = json.load(f)


lengths = []
for row_id, rows in results.items():
    for data in rows:
        if 'rejected' not in data:
            print(data)
            continue
        
        #if len(data['chosen']) > 17000:
        #    continue

        if len(data['chosen']) < MIN_CHOSEN_LENGTH:
            continue

        lengths.append(len(data['chosen']))

        formatted_row = {
            "source": "[FANTASY] " + row_id.strip('.zip'),
            "chosen": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['chosen']}],
            "rejected": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['rejected']}],
            "prompt": data['prompt']
        }

        formatted_data.append(formatted_row)


with open('scenes_with_rewrites_romance.json', 'r') as f:
    results = json.load(f)


lengths = []
for row_id, rows in results.items():
    for data in rows:
        if 'rejected' not in data:
            print(data)
            continue
        
        #if len(data['chosen']) > 17000:
        #    continue

        if len(data['chosen']) < MIN_CHOSEN_LENGTH:
            continue

        lengths.append(len(data['chosen']))

        formatted_row = {
            "source": "[ROMANCE] " + row_id.strip('.zip'),
            "chosen": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['chosen']}],
            "rejected": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['rejected']}],
            "prompt": data['prompt']
        }

        formatted_data.append(formatted_row)


with open('data/site/processing/site_scenes_with_rewrites_fiction.json', 'r') as f:
    results = json.load(f)


lengths = []
for row_id, rows in results.items():
    for data in rows:
        if 'rejected' not in data:
            print(data)
            continue
        
        #if len(data['chosen']) > 17000:
        #    continue

        if len(data['chosen']) < MIN_CHOSEN_LENGTH:
            continue

        lengths.append(len(data['chosen']))

        formatted_row = {
            "source": "[GENERAL FICTION] " + row_id.strip('.zip'),
            "chosen": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['chosen']}],
            "rejected": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['rejected']}],
            "prompt": data['prompt']
        }

        formatted_data.append(formatted_row)


with open('data/site/processing/site_scenes_with_rewrites_fantasy.json', 'r') as f:
    results = json.load(f)


lengths = []
for row_id, rows in results.items():
    for data in rows:
        if 'rejected' not in data:
            print(data)
            continue
        
        #if len(data['chosen']) > 17000:
        #    continue

        if len(data['chosen']) < MIN_CHOSEN_LENGTH:
            continue

        lengths.append(len(data['chosen']))

        formatted_row = {
            "source": "[FANTASY] " + row_id.strip('.zip'),
            "chosen": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['chosen']}],
            "rejected": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['rejected']}],
            "prompt": data['prompt']
        }

        formatted_data.append(formatted_row)



with open('data/site/processing/site_scenes_with_rewrites_scifi.json', 'r') as f:
    results = json.load(f)


lengths = []
for row_id, rows in results.items():
    for data in rows:
        if 'rejected' not in data:
            print(data)
            continue
        
        #if len(data['chosen']) > 17000:
        #    continue

        if len(data['chosen']) < MIN_CHOSEN_LENGTH:
            continue

        lengths.append(len(data['chosen']))

        formatted_row = {
            "source": "[SCIFI] " + row_id.strip('.zip'),
            "chosen": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['chosen']}],
            "rejected": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['rejected']}],
            "prompt": data['prompt']
        }

        formatted_data.append(formatted_row)


with open('data/site/processing/site_scenes_with_rewrites_adventure.json', 'r') as f:
    results = json.load(f)


lengths = []
for row_id, rows in results.items():
    for data in rows:
        if 'rejected' not in data:
            print(data)
            continue
        
        #if len(data['chosen']) > 17000:
        #    continue

        if len(data['chosen']) < MIN_CHOSEN_LENGTH:
            continue

        lengths.append(len(data['chosen']))

        formatted_row = {
            "source": "[ADVENTURE] " + row_id.strip('.zip'),
            "chosen": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['chosen']}],
            "rejected": [{"role": "user", "content": data['prompt']}, {"role": "assistant", "content": data['rejected']}],
            "prompt": data['prompt']
        }

        formatted_data.append(formatted_row)



from datasets import load_dataset

if True:
    # Load the dataset
    gutenberg_01 = load_dataset('jondurbin/gutenberg-dpo-v0.1')

    # Iterate over the dataset
    for row in gutenberg_01['train']:  # Assuming you want to iterate over the 'train' split
        source = row['source']
        prompt = row['prompt']
        chosen = row['chosen']
        rejected = row['rejected']
        formatted_row = {
                "source": source,
                "chosen": [{"role": "user", "content": prompt}, {"role": "assistant", "content": chosen}],
                "rejected": [{"role": "user", "content": prompt}, {"role": "assistant", "content": rejected}],
                "prompt": data['prompt']
            }
        formatted_data.append(formatted_row)



    # Load the dataset
    gutenberg_02 = load_dataset('nbeerbower/gutenberg2-dpo')

    # Iterate over the dataset
    for row in gutenberg_02['train']:  # Assuming you want to iterate over the 'train' split
        source = row['book']
        prompt = row['prompt']
        chosen = row['chosen']
        rejected = row['rejected']
        formatted_row = {
                "source": source,
                "chosen": [{"role": "user", "content": prompt}, {"role": "assistant", "content": chosen}],
                "rejected": [{"role": "user", "content": prompt}, {"role": "assistant", "content": rejected}],
                "prompt": data['prompt']
            }
        formatted_data.append(formatted_row)

if True:
    # Load the dataset
    gutenberg_04 = load_dataset('leftyfeep/Robot.E.Howard.v2')

    # Iterate over the dataset
    for row in gutenberg_04['train']:  # Assuming you want to iterate over the 'train' split
        source = row['source']
        prompt = row['prompt']
        chosen = row['chosen']
        rejected = row['rejected']

        if not prompt or not chosen or not rejected:
            print('!! empty value')
            continue
        formatted_row = {
                "source": source,
                "chosen": [{"role": "user", "content": prompt}, {"role": "assistant", "content": chosen}],
                "rejected": [{"role": "user", "content": prompt}, {"role": "assistant", "content": rejected}],
                "prompt": data['prompt']
            }
        formatted_data.append(formatted_row)
    

import random
random.seed(42)
random.shuffle(formatted_data)
formatted_data.insert(0, max(formatted_data, key=lambda x: len(json.dumps(x['chosen']))))
formatted_data.remove(formatted_data[1])

# Create a Hugging Face Dataset
dataset = Dataset.from_list(formatted_data)

train_test_split = dataset.train_test_split(test_size=0.002)

# Create a DatasetDict with the train and test splits
dataset_dict = DatasetDict({
    "train": train_test_split['train'],
    "test": train_test_split['test']
})

# Login to Hugging Face
HF_TOKEN = ''
login(token=HF_TOKEN)

# Push the dataset to Hugging Face Hub
dataset_dict.push_to_hub("sam-paech/gutenbergs_1_2_3_4-dpo", private=True)


print("Dataset uploaded successfully!")
